# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import torch
import torch.nn as nn
import os
from torch.utils.data import DataLoader , Dataset
from torchvision import transforms
import torchvision
from tqdm import tqdm
import codecs
import re
from PIL import Image, ImageDraw, ImageFont

# %%
IMAGE_SIZE_W = 828
IMAGE_SIZE_H = 1176

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class JapaneseTextDetector(nn.Module):
    def __convBlock(self, ch_in, ch_out, padding, kernel_size):
        conv = nn.Sequential(
            nn.Conv2d(ch_in, ch_out, padding=padding, kernel_size=kernel_size),
            nn.BatchNorm2d(ch_out),
            nn.ReLU(),
            
            nn.Conv2d(ch_out, ch_out, kernel_size=(1, 1)),
            nn.BatchNorm2d(ch_out),
            nn.ReLU()
        )
        
        return conv
    
    def __init__(self, img_h, img_w):
        super(JapaneseTextDetector, self).__init__()
        
        self.img_h = img_h
        self.img_w = img_w
        
        self.conv_block_1 = self.__convBlock(1, 16, padding=(1, 1), kernel_size=(3, 3)) 
        self.max_pool_1 = nn.MaxPool2d((2, 2)) # 1170x826 -> 585x413
        
        self.conv_block_2 = self.__convBlock(16, 32, padding=(1, 1), kernel_size=(3, 3)) 
        self.max_pool_2 = nn.MaxPool2d((2, 2)) # 585x413 -> 292x206
        
        self.conv_block_3 = self.__convBlock(32, 64, padding=(1, 1), kernel_size=(3, 3)) 
        self.max_pool_3 = nn.MaxPool2d((2, 2)) # 292x206 -> 146x103
        
        self.conv_block_4 = self.__convBlock(64, 128, padding=(1, 1), kernel_size=(3, 3)) 
        self.max_pool_4 = nn.MaxPool2d((2, 2)) # 146x103 -> 73x51
        
        self.deconv_1 = nn.ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
        
        self.conv_filter_1 = nn.Conv2d(128, 64, kernel_size=(1, 1))
        self.conv_block_5 = self.__convBlock(64, 64, padding=(1, 1), kernel_size=(3, 3)) 
        
        self.deconv_2 = nn.ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
        
        self.conv_filter_2 = nn.Conv2d(64, 32, kernel_size=(1, 1))
        self.conv_block_6 = self.__convBlock(32, 32, padding=(1, 1), kernel_size=(3, 3)) 
        
        self.deconv_3 = nn.ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 0), output_padding=(1, 0))
        
        self.conv_block_7 = nn.Conv2d(32, 1, padding=(1, 1), kernel_size=(3, 3))
        
    def forward(self, x):
        c1 = self.conv_block_1(x)
        x = self.max_pool_1(c1)
        
        c2 = self.conv_block_2(x)
        x = self.max_pool_2(c2)
        
        c3 = self.conv_block_3(x)
        x = self.max_pool_3(c3)
        
        x = self.conv_block_4(x)
        
        x = self.deconv_1(x)
        
        x = torch.cat((c3, x), 1)
        x = self.conv_filter_1(x)
        
        x = self.conv_block_5(x)
        x = self.deconv_2(x)
        
        x = torch.cat((c2, x), 1)
        x = self.conv_filter_2(x)
        
        x = self.conv_block_6(x)
        x = self.deconv_3(x)
        
        x = torch.cat((c1, x), 1)
        x = self.conv_block_7(x)

        return x

# %%
class Resnet34(nn.Module):
    def __init__(self):
        super(Resnet34, self).__init__()
        
        resnet34 = torchvision.models.resnet34()
        
        self.conv1 = resnet34.conv1
        self.maxpool = resnet34.maxpool
        self.layer1 = resnet34.layer1
        self.layer2 = resnet34.layer2
        self.layer3 = resnet34.layer3
        self.layer4 = resnet34.layer4
        
        
    def forward(self, x):
        x = self.conv1(x)
        e1 = self.maxpool(x)
        e1 = self.layer1(e1)
        e2 = self.layer2(e1)
        e3 = self.layer3(e2)
        e4 = self.layer4(e3)
        
        return x, e1, e2, e3, e4

# %%
class PretrainedTextDetector(nn.Module):
    def __doubleConv(self, ch_in, ch_out, padding, kernel_size):
        conv = nn.Sequential(
            nn.Conv2d(ch_in, ch_out, padding=padding, kernel_size=kernel_size),
            nn.BatchNorm2d(ch_out),
            nn.ReLU(),
            
            nn.Conv2d(ch_out, ch_out, padding=padding, kernel_size=kernel_size),
            nn.BatchNorm2d(ch_out),
            nn.ReLU(),
        )
        
        return conv
    
    def __init__(self, img_h, img_w, finetune=False):
        super(PretrainedTextDetector, self).__init__()

        self.img_h = img_h
        self.img_w = img_w
        self.finetune = finetune
        self.resnet = Resnet34()
        self.resnet.eval()
        
        self.conv_1 = self.__doubleConv(512, 512, (1, 1), (3, 3))
        self.deconv_1 = nn.ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
        self.conv_2 = self.__doubleConv(512, 256, (1, 1), (3, 3))
        self.deconv_2 = nn.ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(0, 1))
        self.conv_3 = self.__doubleConv(256, 128, (1, 1), (3, 3))
        self.deconv_3 = nn.ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 0))
        self.conv_4 = self.__doubleConv(128, 64, (1, 1), (3, 3))
        self.deconv_4 = nn.ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
        self.conv_5 = self.__doubleConv(96, 64, (1, 1), (3, 3))
        self.deconv_5 = nn.ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
        self.conv_6 = self.__doubleConv(32, 16, (1, 1), (3, 3))
        self.out_conv = nn.Conv2d(16, 1, padding=(1, 1), kernel_size=(3, 3))
        
        for param in self.parameters():
            param.requires_grad = True

    def forward(self, x):
        if self.finetune:
            e0, e1, e2, e3, e4 = self.resnet(x)
        else:
            with torch.no_grad():
                e0, e1, e2, e3, e4 = self.resnet(x)
        x = self.conv_1(e4)
        x = self.deconv_1(x)
        x = torch.cat((x, e3), 1)
        x = self.conv_2(x)
        x = self.deconv_2(x)
        x = torch.cat((x, e2), 1)
        x = self.conv_3(x)
        x = self.deconv_3(x)
        x = torch.cat((x, e1), 1)
        x = self.conv_4(x)
        x = self.deconv_4(x)
        x = torch.cat((x, e0), 1)
        x = self.conv_5(x)
        x = self.deconv_5(x)
        x = self.conv_6(x)
        x = self.out_conv(x)
        return x

# %%
model = PretrainedTextDetector(IMAGE_SIZE_W, IMAGE_SIZE_H, finetune=True)

model.load_state_dict(torch.load('model.pth'))
# Out:
# <All keys matched successfully>

# %%
model.eval()

random_data = torch.rand(1, 3, IMAGE_SIZE_H, IMAGE_SIZE_W)

model(random_data)

model_jit = torch.jit.script(model)

# %%
torch.onnx.export(model_jit, random_data, "model.onnx", verbose=True)
# Out:
# Exported graph: graph(%x.1 : Float(1, 3, 1176, 828, strides=[2921184, 973728, 828, 1], requires_grad=0, device=cpu),
#       %resnet.conv1.weight : Float(64, 3, 7, 7, strides=[147, 49, 7, 1], requires_grad=0, device=cpu),
#       %deconv_1.weight : Float(512, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %deconv_1.bias : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %deconv_2.weight : Float(256, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %deconv_2.bias : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %deconv_3.weight : Float(128, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %deconv_3.bias : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %deconv_4.weight : Float(64, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %deconv_4.bias : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %deconv_5.weight : Float(64, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %deconv_5.bias : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %out_conv.weight : Float(1, 16, 3, 3, strides=[144, 9, 3, 1], requires_grad=0, device=cpu),
#       %out_conv.bias : Float(1, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_428 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_429 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_431 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_432 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_434 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_435 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_437 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_438 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_440 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_441 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_443 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_444 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_446 : Float(128, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_447 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_449 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_450 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_452 : Float(128, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_453 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_455 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_456 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_458 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_459 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_461 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_462 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_464 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_465 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_467 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_468 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_470 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_471 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_473 : Float(256, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_474 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_476 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_477 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_479 : Float(256, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_480 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_482 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_483 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_485 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_486 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_488 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_489 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_491 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_492 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_494 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_495 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_497 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_498 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_500 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_501 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_503 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_504 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_506 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_507 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_509 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_510 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_512 : Float(512, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_513 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_515 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_516 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_518 : Float(512, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_519 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_521 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_522 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_524 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_525 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_527 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_528 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_530 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_531 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_533 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_534 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_536 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_537 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_539 : Float(256, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_540 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_542 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_543 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_545 : Float(128, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_546 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_548 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_549 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_551 : Float(64, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_552 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_554 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_555 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_557 : Float(64, 96, 3, 3, strides=[864, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_558 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_560 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_561 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_563 : Float(16, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_564 : Float(16, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_566 : Float(16, 16, 3, 3, strides=[144, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_567 : Float(16, strides=[1], requires_grad=0, device=cpu)):
#   %/resnet/Conv_output_0 : Float(1, 64, 588, 414, strides=[15579648, 243432, 414, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[2, 2], onnx_name="/resnet/Conv"](%x.1, %resnet.conv1.weight), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/MaxPool_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::MaxPool[ceil_mode=0, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2], onnx_name="/resnet/MaxPool"](%/resnet/Conv_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:782:11
#   %/resnet/Conv_1_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_1"](%/resnet/MaxPool_output_0, %onnx::Conv_428, %onnx::Conv_429), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu"](%/resnet/Conv_1_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_2_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_2"](%/resnet/Relu_output_0, %onnx::Conv_431, %onnx::Conv_432), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add"](%/resnet/Conv_2_output_0, %/resnet/MaxPool_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_1_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_1"](%/resnet/Add_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_3_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_3"](%/resnet/Relu_1_output_0, %onnx::Conv_434, %onnx::Conv_435), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_2_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_2"](%/resnet/Conv_3_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_4_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_4"](%/resnet/Relu_2_output_0, %onnx::Conv_437, %onnx::Conv_438), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_1_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_1"](%/resnet/Conv_4_output_0, %/resnet/Relu_1_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_3_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_3"](%/resnet/Add_1_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_5_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_5"](%/resnet/Relu_3_output_0, %onnx::Conv_440, %onnx::Conv_441), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_4_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_4"](%/resnet/Conv_5_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_6_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_6"](%/resnet/Relu_4_output_0, %onnx::Conv_443, %onnx::Conv_444), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_2_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_2"](%/resnet/Conv_6_output_0, %/resnet/Relu_3_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_5_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_5"](%/resnet/Add_2_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_7_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2], onnx_name="/resnet/Conv_7"](%/resnet/Relu_5_output_0, %onnx::Conv_446, %onnx::Conv_447), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_6_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_6"](%/resnet/Conv_7_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_8_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/resnet/Conv_8"](%/resnet/Relu_5_output_0, %onnx::Conv_452, %onnx::Conv_453), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Conv_9_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_9"](%/resnet/Relu_6_output_0, %onnx::Conv_449, %onnx::Conv_450), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_3_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_3"](%/resnet/Conv_9_output_0, %/resnet/Conv_8_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_7_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_7"](%/resnet/Add_3_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_10_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_10"](%/resnet/Relu_7_output_0, %onnx::Conv_455, %onnx::Conv_456), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_8_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_8"](%/resnet/Conv_10_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_11_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_11"](%/resnet/Relu_8_output_0, %onnx::Conv_458, %onnx::Conv_459), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_4_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_4"](%/resnet/Conv_11_output_0, %/resnet/Relu_7_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_9_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_9"](%/resnet/Add_4_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_12_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_12"](%/resnet/Relu_9_output_0, %onnx::Conv_461, %onnx::Conv_462), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_10_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_10"](%/resnet/Conv_12_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_13_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_13"](%/resnet/Relu_10_output_0, %onnx::Conv_464, %onnx::Conv_465), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_5_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_5"](%/resnet/Conv_13_output_0, %/resnet/Relu_9_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_11_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_11"](%/resnet/Add_5_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_14_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_14"](%/resnet/Relu_11_output_0, %onnx::Conv_467, %onnx::Conv_468), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_12_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_12"](%/resnet/Conv_14_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_15_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_15"](%/resnet/Relu_12_output_0, %onnx::Conv_470, %onnx::Conv_471), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_6_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_6"](%/resnet/Conv_15_output_0, %/resnet/Relu_11_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_13_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_13"](%/resnet/Add_6_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_16_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2], onnx_name="/resnet/Conv_16"](%/resnet/Relu_13_output_0, %onnx::Conv_473, %onnx::Conv_474), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_14_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_14"](%/resnet/Conv_16_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_17_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/resnet/Conv_17"](%/resnet/Relu_13_output_0, %onnx::Conv_479, %onnx::Conv_480), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Conv_18_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_18"](%/resnet/Relu_14_output_0, %onnx::Conv_476, %onnx::Conv_477), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_7_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_7"](%/resnet/Conv_18_output_0, %/resnet/Conv_17_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_15_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_15"](%/resnet/Add_7_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_19_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_19"](%/resnet/Relu_15_output_0, %onnx::Conv_482, %onnx::Conv_483), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_16_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_16"](%/resnet/Conv_19_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_20_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_20"](%/resnet/Relu_16_output_0, %onnx::Conv_485, %onnx::Conv_486), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_8_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_8"](%/resnet/Conv_20_output_0, %/resnet/Relu_15_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_17_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_17"](%/resnet/Add_8_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_21_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_21"](%/resnet/Relu_17_output_0, %onnx::Conv_488, %onnx::Conv_489), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_18_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_18"](%/resnet/Conv_21_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_22_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_22"](%/resnet/Relu_18_output_0, %onnx::Conv_491, %onnx::Conv_492), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_9_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_9"](%/resnet/Conv_22_output_0, %/resnet/Relu_17_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_19_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_19"](%/resnet/Add_9_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_23_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_23"](%/resnet/Relu_19_output_0, %onnx::Conv_494, %onnx::Conv_495), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_20_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_20"](%/resnet/Conv_23_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_24_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_24"](%/resnet/Relu_20_output_0, %onnx::Conv_497, %onnx::Conv_498), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_10_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_10"](%/resnet/Conv_24_output_0, %/resnet/Relu_19_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_21_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_21"](%/resnet/Add_10_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_25_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_25"](%/resnet/Relu_21_output_0, %onnx::Conv_500, %onnx::Conv_501), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_22_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_22"](%/resnet/Conv_25_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_26_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_26"](%/resnet/Relu_22_output_0, %onnx::Conv_503, %onnx::Conv_504), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_11_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_11"](%/resnet/Conv_26_output_0, %/resnet/Relu_21_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_23_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_23"](%/resnet/Add_11_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_27_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_27"](%/resnet/Relu_23_output_0, %onnx::Conv_506, %onnx::Conv_507), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_24_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_24"](%/resnet/Conv_27_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_28_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_28"](%/resnet/Relu_24_output_0, %onnx::Conv_509, %onnx::Conv_510), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_12_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_12"](%/resnet/Conv_28_output_0, %/resnet/Relu_23_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_25_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_25"](%/resnet/Add_12_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_29_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2], onnx_name="/resnet/Conv_29"](%/resnet/Relu_25_output_0, %onnx::Conv_512, %onnx::Conv_513), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_26_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_26"](%/resnet/Conv_29_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_30_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/resnet/Conv_30"](%/resnet/Relu_25_output_0, %onnx::Conv_518, %onnx::Conv_519), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Conv_31_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_31"](%/resnet/Relu_26_output_0, %onnx::Conv_515, %onnx::Conv_516), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_13_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_13"](%/resnet/Conv_31_output_0, %/resnet/Conv_30_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_27_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_27"](%/resnet/Add_13_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_32_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_32"](%/resnet/Relu_27_output_0, %onnx::Conv_521, %onnx::Conv_522), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_28_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_28"](%/resnet/Conv_32_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_33_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_33"](%/resnet/Relu_28_output_0, %onnx::Conv_524, %onnx::Conv_525), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_14_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_14"](%/resnet/Conv_33_output_0, %/resnet/Relu_27_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_29_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_29"](%/resnet/Add_14_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_34_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_34"](%/resnet/Relu_29_output_0, %onnx::Conv_527, %onnx::Conv_528), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Relu_30_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_30"](%/resnet/Conv_34_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/resnet/Conv_35_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/resnet/Conv_35"](%/resnet/Relu_30_output_0, %onnx::Conv_530, %onnx::Conv_531), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/resnet/Add_15_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Add[onnx_name="/resnet/Add_15"](%/resnet/Conv_35_output_0, %/resnet/Relu_29_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torchvision/models/resnet.py:102:8
#   %/resnet/Relu_31_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Relu[onnx_name="/resnet/Relu_31"](%/resnet/Add_15_output_0), scope: PretrainedTextDetector::/Resnet34::resnet # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1455:17
#   %/conv_1/Conv_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_1/Conv"](%/resnet/Relu_31_output_0, %onnx::Conv_533, %onnx::Conv_534), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_1 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_1/Relu_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Relu[onnx_name="/conv_1/Relu"](%/conv_1/Conv_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_1 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %/conv_1/Conv_1_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_1/Conv_1"](%/conv_1/Relu_output_0, %onnx::Conv_536, %onnx::Conv_537), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_1 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_1/Relu_1_output_0 : Float(1, 512, 37, 26, strides=[492544, 962, 26, 1], device=cpu) = onnx::Relu[onnx_name="/conv_1/Relu_1"](%/conv_1/Conv_1_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_1 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %/deconv_1/ConvTranspose_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[1, 1], pads=[1, 1, 1, 1], strides=[2, 2], onnx_name="/deconv_1/ConvTranspose"](%/conv_1/Relu_1_output_0, %deconv_1.weight, %deconv_1.bias), scope: PretrainedTextDetector::/torch.nn.modules.conv.ConvTranspose2d::deconv_1 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:956:15
#   %/Concat_output_0 : Float(1, 512, 74, 52, strides=[1970176, 3848, 52, 1], device=cpu) = onnx::Concat[axis=1, onnx_name="/Concat"](%/deconv_1/ConvTranspose_output_0, %/resnet/Relu_25_output_0), scope: PretrainedTextDetector:: # /tmp/ipykernel_51584/1431701725.py:62:12
#   %/conv_2/Conv_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_2/Conv"](%/Concat_output_0, %onnx::Conv_539, %onnx::Conv_540), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_2 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_2/Relu_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/conv_2/Relu"](%/conv_2/Conv_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_2 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %/conv_2/Conv_1_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_2/Conv_1"](%/conv_2/Relu_output_0, %onnx::Conv_542, %onnx::Conv_543), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_2 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_2/Relu_1_output_0 : Float(1, 256, 74, 52, strides=[985088, 3848, 52, 1], device=cpu) = onnx::Relu[onnx_name="/conv_2/Relu_1"](%/conv_2/Conv_1_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_2 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %/deconv_2/ConvTranspose_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[0, 1], pads=[1, 1, 1, 1], strides=[2, 2], onnx_name="/deconv_2/ConvTranspose"](%/conv_2/Relu_1_output_0, %deconv_2.weight, %deconv_2.bias), scope: PretrainedTextDetector::/torch.nn.modules.conv.ConvTranspose2d::deconv_2 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:956:15
#   %/Concat_1_output_0 : Float(1, 256, 147, 104, strides=[3913728, 15288, 104, 1], device=cpu) = onnx::Concat[axis=1, onnx_name="/Concat_1"](%/deconv_2/ConvTranspose_output_0, %/resnet/Relu_13_output_0), scope: PretrainedTextDetector:: # /tmp/ipykernel_51584/1431701725.py:68:12
#   %/conv_3/Conv_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_3/Conv"](%/Concat_1_output_0, %onnx::Conv_545, %onnx::Conv_546), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_3 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_3/Relu_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Relu[onnx_name="/conv_3/Relu"](%/conv_3/Conv_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_3 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %/conv_3/Conv_1_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_3/Conv_1"](%/conv_3/Relu_output_0, %onnx::Conv_548, %onnx::Conv_549), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_3 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_3/Relu_1_output_0 : Float(1, 128, 147, 104, strides=[1956864, 15288, 104, 1], device=cpu) = onnx::Relu[onnx_name="/conv_3/Relu_1"](%/conv_3/Conv_1_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_3 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %/deconv_3/ConvTranspose_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[1, 0], pads=[1, 1, 1, 1], strides=[2, 2], onnx_name="/deconv_3/ConvTranspose"](%/conv_3/Relu_1_output_0, %deconv_3.weight, %deconv_3.bias), scope: PretrainedTextDetector::/torch.nn.modules.conv.ConvTranspose2d::deconv_3 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:956:15
#   %/Concat_2_output_0 : Float(1, 128, 294, 207, strides=[7789824, 60858, 207, 1], device=cpu) = onnx::Concat[axis=1, onnx_name="/Concat_2"](%/deconv_3/ConvTranspose_output_0, %/resnet/Relu_5_output_0), scope: PretrainedTextDetector:: # /tmp/ipykernel_51584/1431701725.py:74:12
#   %/conv_4/Conv_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_4/Conv"](%/Concat_2_output_0, %onnx::Conv_551, %onnx::Conv_552), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_4 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_4/Relu_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Relu[onnx_name="/conv_4/Relu"](%/conv_4/Conv_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_4 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %/conv_4/Conv_1_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_4/Conv_1"](%/conv_4/Relu_output_0, %onnx::Conv_554, %onnx::Conv_555), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_4 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_4/Relu_1_output_0 : Float(1, 64, 294, 207, strides=[3894912, 60858, 207, 1], device=cpu) = onnx::Relu[onnx_name="/conv_4/Relu_1"](%/conv_4/Conv_1_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_4 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %/deconv_4/ConvTranspose_output_0 : Float(1, 32, 588, 414, strides=[7789824, 243432, 414, 1], device=cpu) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[1, 1], pads=[1, 1, 1, 1], strides=[2, 2], onnx_name="/deconv_4/ConvTranspose"](%/conv_4/Relu_1_output_0, %deconv_4.weight, %deconv_4.bias), scope: PretrainedTextDetector::/torch.nn.modules.conv.ConvTranspose2d::deconv_4 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:956:15
#   %/Concat_3_output_0 : Float(1, 96, 588, 414, strides=[23369472, 243432, 414, 1], device=cpu) = onnx::Concat[axis=1, onnx_name="/Concat_3"](%/deconv_4/ConvTranspose_output_0, %/resnet/Conv_output_0), scope: PretrainedTextDetector:: # /tmp/ipykernel_51584/1431701725.py:80:12
#   %/conv_5/Conv_output_0 : Float(1, 64, 588, 414, strides=[15579648, 243432, 414, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_5/Conv"](%/Concat_3_output_0, %onnx::Conv_557, %onnx::Conv_558), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_5 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_5/Relu_output_0 : Float(1, 64, 588, 414, strides=[15579648, 243432, 414, 1], device=cpu) = onnx::Relu[onnx_name="/conv_5/Relu"](%/conv_5/Conv_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_5 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %/conv_5/Conv_1_output_0 : Float(1, 64, 588, 414, strides=[15579648, 243432, 414, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_5/Conv_1"](%/conv_5/Relu_output_0, %onnx::Conv_560, %onnx::Conv_561), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_5 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_5/Relu_1_output_0 : Float(1, 64, 588, 414, strides=[15579648, 243432, 414, 1], device=cpu) = onnx::Relu[onnx_name="/conv_5/Relu_1"](%/conv_5/Conv_1_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_5 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %/deconv_5/ConvTranspose_output_0 : Float(1, 32, 1176, 828, strides=[31159296, 973728, 828, 1], device=cpu) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[1, 1], pads=[1, 1, 1, 1], strides=[2, 2], onnx_name="/deconv_5/ConvTranspose"](%/conv_5/Relu_1_output_0, %deconv_5.weight, %deconv_5.bias), scope: PretrainedTextDetector::/torch.nn.modules.conv.ConvTranspose2d::deconv_5 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:956:15
#   %/conv_6/Conv_output_0 : Float(1, 16, 1176, 828, strides=[15579648, 973728, 828, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_6/Conv"](%/deconv_5/ConvTranspose_output_0, %onnx::Conv_563, %onnx::Conv_564), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_6 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_6/Relu_output_0 : Float(1, 16, 1176, 828, strides=[15579648, 973728, 828, 1], device=cpu) = onnx::Relu[onnx_name="/conv_6/Relu"](%/conv_6/Conv_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_6 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %/conv_6/Conv_1_output_0 : Float(1, 16, 1176, 828, strides=[15579648, 973728, 828, 1], device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/conv_6/Conv_1"](%/conv_6/Relu_output_0, %onnx::Conv_566, %onnx::Conv_567), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_6 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   %/conv_6/Relu_1_output_0 : Float(1, 16, 1176, 828, strides=[15579648, 973728, 828, 1], device=cpu) = onnx::Relu[onnx_name="/conv_6/Relu_1"](%/conv_6/Conv_1_output_0), scope: PretrainedTextDetector::/torch.nn.modules.container.Sequential::conv_6 # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/functional.py:1457:17
#   %x.40 : Float(1, 1, 1176, 828, strides=[973728, 973728, 828, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/out_conv/Conv"](%/conv_6/Relu_1_output_0, %out_conv.weight, %out_conv.bias), scope: PretrainedTextDetector::/torch.nn.modules.conv.Conv2d::out_conv # /home/dcnick3/.conda/envs/ml/lib/python3.10/site-packages/torch/nn/modules/conv.py:459:15
#   return (%x.40)
